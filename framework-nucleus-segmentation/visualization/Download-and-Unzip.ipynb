# %% [markdown]
# # Sample script to download and unzip datasets from Figshare

# %%
from download_util import *

# %%
GT_URL = 'https://ndownloader.figshare.com/files/22185189'
GS_URL = 'https://ndownloader.figshare.com/files/22185111'
INF_URL = 'https://ndownloader.figshare.com/files/22248840'


GT_PATH = 'GT.zip'
GS_PATH = 'Greyscale.zip'
INF_PATH = 'Inference.zip'

# %%
download_and_unzip_datasets(GT_URL, GT_PATH)
download_and_unzip_datasets(GS_URL, GS_PATH)
#download_and_unzip_datasets(INF_URL, INF_PATH)

# %%
# !ls -R
# Out:
# Download and Unzip.ipynb GreyScale                __MACOSX
# GT                       Greyscale.zip
# GT.zip                   Inference.zip
#
# ./GT:
# BABE_Biological             HiTIF_Laurent_Original
# BABE_Original               HiTIF_Laurent_Technical
# BABE_Technical              Manasi_Original
# HiTIF_Colorectal_Biological Manasi_Technical
# HiTIF_Colorectal_Original
#
# ./GT/BABE_Biological:
# Plate1_E03_T0001FF001Zall.tif Plate1_E03_T0001FF005Zall.tif
# Plate1_E03_T0001FF002Zall.tif Plate1_E03_T0001FF006Zall.tif
# Plate1_E03_T0001FF003Zall.tif Plate1_E03_T0001FF007Zall.tif
# Plate1_E03_T0001FF004Zall.tif
#
# ./GT/BABE_Original:
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F001Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F002Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F003Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F004Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F005Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F006Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F007Zall.tif
#
# ./GT/BABE_Technical:
# image_0.tif image_2.tif image_4.tif image_6.tif
# image_1.tif image_3.tif image_5.tif
#
# ./GT/HiTIF_Colorectal_Biological:
# AUTO0218_N07_T0001F004L01A01Z01C01.tif
#
# ./GT/HiTIF_Colorectal_Original:
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_B07_T0001F002L01A01Z01C01.tif
#
# ./GT/HiTIF_Laurent_Original:
# AUTO0496_N14_T0001F002L01A01Z01C01.tif
#
# ./GT/HiTIF_Laurent_Technical:
# AUTO0496_J14_T0001F001L01A01Z01C01.tif
#
# ./GT/Manasi_Original:
# Plate1_M19_T0001F001L01A01Z01C01.tif
#
# ./GT/Manasi_Technical:
# Plate1_M21_T0001F003L01A01Z01C01.tif
#
# ./GreyScale:
# BABE_Biological             HiTIF_Laurent_Original
# BABE_Original               HiTIF_Laurent_Technical
# BABE_Technical              Manasi_Original
# HiTIF_Colorectal_Biological Manasi_Technical
# HiTIF_Colorectal_Original
#
# ./GreyScale/BABE_Biological:
# Plate1_E03_T0001FF001Zall.tif Plate1_E03_T0001FF005Zall.tif
# Plate1_E03_T0001FF002Zall.tif Plate1_E03_T0001FF006Zall.tif
# Plate1_E03_T0001FF003Zall.tif Plate1_E03_T0001FF007Zall.tif
# Plate1_E03_T0001FF004Zall.tif
#
# ./GreyScale/BABE_Original:
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F001Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F002Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F003Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F004Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F005Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F006Zall.tif
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_E03_T0001F007Zall.tif
#
# ./GreyScale/BABE_Technical:
# image_0.tif image_2.tif image_4.tif image_6.tif
# image_1.tif image_3.tif image_5.tif
#
# ./GreyScale/HiTIF_Colorectal_Biological:
# AUTO0218_N07_T0001F004L01A01Z01C01.tif
#
# ./GreyScale/HiTIF_Colorectal_Original:
# AssayPlate_PerkinElmer_CellCarrier-384 Ultra_B07_T0001F002L01A01Z01C01.tif
#
# ./GreyScale/HiTIF_Laurent_Original:
# AUTO0496_N14_T0001F002L01A01Z01C01.tif
#
# ./GreyScale/HiTIF_Laurent_Technical:
# AUTO0496_J14_T0001F001L01A01Z01C01.tif
#
# ./GreyScale/Manasi_Original:
# Plate1_M19_T0001F001L01A01Z01C01.tif
#
# ./GreyScale/Manasi_Technical:
# Plate1_M21_T0001F003L01A01Z01C01.tif
#
# ./__MACOSX:
# GT        GreyScale
#
# ./__MACOSX/GT:
# BABE_Biological             HiTIF_Laurent_Original
# BABE_Original               HiTIF_Laurent_Technical
# BABE_Technical              Manasi_Original
# HiTIF_Colorectal_Biological Manasi_Technical
# HiTIF_Colorectal_Original
#
# ./__MACOSX/GT/BABE_Biological:
#
# ./__MACOSX/GT/BABE_Original:
#
# ./__MACOSX/GT/BABE_Technical:
#
# ./__MACOSX/GT/HiTIF_Colorectal_Biological:
#
# ./__MACOSX/GT/HiTIF_Colorectal_Original:
#
# ./__MACOSX/GT/HiTIF_Laurent_Original:
#
# ./__MACOSX/GT/HiTIF_Laurent_Technical:
#
# ./__MACOSX/GT/Manasi_Original:
#
# ./__MACOSX/GT/Manasi_Technical:
#
# ./__MACOSX/GreyScale:
# BABE_Biological             HiTIF_Laurent_Original
# BABE_Original               HiTIF_Laurent_Technical
# BABE_Technical              Manasi_Original
# HiTIF_Colorectal_Biological Manasi_Technical
# HiTIF_Colorectal_Original
#
# ./__MACOSX/GreyScale/BABE_Biological:
#
# ./__MACOSX/GreyScale/BABE_Original:
#
# ./__MACOSX/GreyScale/BABE_Technical:
#
# ./__MACOSX/GreyScale/HiTIF_Colorectal_Biological:
#
# ./__MACOSX/GreyScale/HiTIF_Colorectal_Original:
#
# ./__MACOSX/GreyScale/HiTIF_Laurent_Original:
#
# ./__MACOSX/GreyScale/HiTIF_Laurent_Technical:
#
# ./__MACOSX/GreyScale/Manasi_Original:
#
# ./__MACOSX/GreyScale/Manasi_Technical:
